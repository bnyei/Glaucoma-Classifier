# %%
from google.colab import drive
drive.mount('/content/drive')

PROJECT_PATH = "/content/drive/MyDrive/mResearch"
# %cd $PROJECT_PATH
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/mResearch

# %%
# !pip install -q tensorflow scikit-learn pandas matplotlib tqdm

# %%
import sys
import os

sys.path.append(PROJECT_PATH)

print("✅ Project path added")
# Out:
# ✅ Project path added

# %%
from src.config import Config
from experiments.run_kfold import main as run_kfold
from experiments.external_validation import main as run_external

# %%
cfg = Config()

# EXPERIMENT CONTROL
cfg.EXPERIMENT_NAME = "fusion_model_1 (New)"
cfg.FUSION_STRATEGY = "model_1"

# DATA
cfg.TRAIN_PATH = os.path.join(PROJECT_PATH, "datasets/training")
cfg.EXTERNAL_PATH  = os.path.join(PROJECT_PATH, "datasets/testing")

# TRAINING
cfg.BATCH_SIZE = 4
cfg.EPOCHS = 20
cfg.N_SPLITS = 5

# METRICS
cfg.BOOTSTRAP_SAMPLES = 1000
cfg.CI_ALPHA = 0.95

# AUGMENTATION
cfg.USE_AUGMENTATION = True

cfg.set_seed()

print("✅ Config ready")
# Out:
# ✅ Config ready

# %%
print("🚀 Running K-Fold Training...")

run_kfold(cfg)
# Out:
# 🚀 Running K-Fold Training...
#
# 🚀 Running K-Fold Experiment
# Fusion Strategy: model_1
#
# 📂 Loading TRAINING data...
#
# 📂 Loading dataset from: /content/drive/MyDrive/mResearch/datasets/training
# Class 'Glaucoma': 23 aligned samples
# Class 'Non-glaucoma': 33 aligned samples
#
# ✅ Total aligned samples: 56
#
# 📊 K-FOLD DISTRIBUTION SUMMARY
#
# Fold 1
#  Train size: 44, Class balance: [18 26]
#  Val size:   12, Class balance: [5 7]
# ----------------------------------------
# Fold 2
#  Train size: 45, Class balance: [18 27]
#  Val size:   11, Class balance: [5 6]
# ----------------------------------------
# Fold 3
#  Train size: 45, Class balance: [18 27]
#  Val size:   11, Class balance: [5 6]
# ----------------------------------------
# Fold 4
#  Train size: 45, Class balance: [19 26]
#  Val size:   11, Class balance: [4 7]
# ----------------------------------------
# Fold 5
#  Train size: 45, Class balance: [19 26]
#  Val size:   11, Class balance: [4 7]
# ----------------------------------------
#
# ========== FOLD 1/5 ==========
# [fusion_model_1 (New)] Training Fold 1
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19993432/19993432 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234545216/234545216 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 177s 8s/step - accuracy: 0.5000 - auc: 0.4690 - loss: 0.9468 - val_accuracy: 0.8333 - val_auc: 0.8571 - val_loss: 0.6762 - learning_rate: 1.0000e-04
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.7045 - auc: 0.6923 - loss: 0.6753 - val_accuracy: 0.9167 - val_auc: 0.9286 - val_loss: 0.6593 - learning_rate: 1.0000e-04
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 48s 4s/step - accuracy: 0.7955 - auc: 0.8782 - loss: 0.4433 - val_accuracy: 0.9167 - val_auc: 0.9429 - val_loss: 0.6465 - learning_rate: 1.0000e-04
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 48s 4s/step - accuracy: 0.8182 - auc: 0.9209 - loss: 0.3457 - val_accuracy: 0.9167 - val_auc: 0.9429 - val_loss: 0.6344 - learning_rate: 1.0000e-04
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 49s 4s/step - accuracy: 0.9318 - auc: 0.9786 - loss: 0.1814 - val_accuracy: 0.8333 - val_auc: 0.9429 - val_loss: 0.6254 - learning_rate: 1.0000e-04
# Epoch 6/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 81s 4s/step - accuracy: 0.8636 - auc: 0.9199 - loss: 0.3614 - val_accuracy: 0.9167 - val_auc: 0.9429 - val_loss: 0.6130 - learning_rate: 1.0000e-04
# Epoch 7/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 84s 5s/step - accuracy: 0.8409 - auc: 0.9573 - loss: 0.2947 - val_accuracy: 0.9167 - val_auc: 0.9714 - val_loss: 0.6086 - learning_rate: 1.0000e-04
# Epoch 8/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 81s 5s/step - accuracy: 0.8409 - auc: 0.9167 - loss: 0.3933 - val_accuracy: 0.9167 - val_auc: 0.9571 - val_loss: 0.6013 - learning_rate: 1.0000e-04
# Epoch 9/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 51s 5s/step - accuracy: 0.8409 - auc: 0.9199 - loss: 0.3844 - val_accuracy: 0.9167 - val_auc: 0.9571 - val_loss: 0.5899 - learning_rate: 1.0000e-04
# Epoch 10/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 49s 4s/step - accuracy: 0.9545 - auc: 0.9818 - loss: 0.1573 - val_accuracy: 0.9167 - val_auc: 0.9571 - val_loss: 0.5776 - learning_rate: 1.0000e-04
# Epoch 11/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 48s 4s/step - accuracy: 0.9091 - auc: 0.9850 - loss: 0.1582 - val_accuracy: 0.9167 - val_auc: 0.9714 - val_loss: 0.5700 - learning_rate: 1.0000e-04
# Epoch 12/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 51s 5s/step - accuracy: 0.9318 - auc: 0.9915 - loss: 0.1429 - val_accuracy: 0.9167 - val_auc: 0.9571 - val_loss: 0.5629 - learning_rate: 1.0000e-04
# Epoch 13/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 49s 5s/step - accuracy: 0.9318 - auc: 0.9957 - loss: 0.0975 - val_accuracy: 0.9167 - val_auc: 0.9429 - val_loss: 0.5572 - learning_rate: 1.0000e-04
# Epoch 14/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 48s 4s/step - accuracy: 0.8636 - auc: 0.9380 - loss: 0.3202 - val_accuracy: 0.9167 - val_auc: 0.9571 - val_loss: 0.5524 - learning_rate: 1.0000e-04
# Epoch 15/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 83s 4s/step - accuracy: 0.9318 - auc: 0.9936 - loss: 0.1249 - val_accuracy: 0.9167 - val_auc: 0.9429 - val_loss: 0.5510 - learning_rate: 1.0000e-04
# Epoch 16/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 50s 5s/step - accuracy: 0.9318 - auc: 0.9530 - loss: 0.2508 - val_accuracy: 0.9167 - val_auc: 0.9286 - val_loss: 0.5442 - learning_rate: 1.0000e-04
# Epoch 17/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 84s 5s/step - accuracy: 0.8864 - auc: 0.9615 - loss: 0.2629 - val_accuracy: 0.9167 - val_auc: 0.9714 - val_loss: 0.5346 - learning_rate: 1.0000e-04
# Epoch 18/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 49s 4s/step - accuracy: 0.8864 - auc: 0.9637 - loss: 0.2400 - val_accuracy: 0.9167 - val_auc: 0.9714 - val_loss: 0.5223 - learning_rate: 1.0000e-04
# Epoch 19/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 48s 4s/step - accuracy: 0.8864 - auc: 0.9637 - loss: 0.2376 - val_accuracy: 0.9167 - val_auc: 0.9571 - val_loss: 0.5134 - learning_rate: 1.0000e-04
# Epoch 20/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 48s 4s/step - accuracy: 0.8636 - auc: 0.9530 - loss: 0.2649 - val_accuracy: 0.9167 - val_auc: 0.8857 - val_loss: 0.5073 - learning_rate: 1.0000e-04
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# DEBUG: unique classes in y_true → [0 1]
# Fold 1 Metrics:
# accuracy: 0.9167 (CI 0.7500 - 1.0000)
# sensitivity: 0.8571 (CI 0.5000 - 1.0000)
# specificity: 1.0000 (CI 1.0000 - 1.0000)
# auc: 0.8857 (CI 0.5833 - 1.0000)
#
# ========== FOLD 2/5 ==========
# [fusion_model_1 (New)] Training Fold 2
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 171s 7s/step - accuracy: 0.5556 - auc: 0.5504 - loss: 0.8561 - val_accuracy: 0.5455 - val_auc: 0.8667 - val_loss: 0.6700 - learning_rate: 1.0000e-04
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 49s 4s/step - accuracy: 0.8444 - auc: 0.9208 - loss: 0.3603 - val_accuracy: 0.5455 - val_auc: 0.9333 - val_loss: 0.6536 - learning_rate: 1.0000e-04
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 49s 4s/step - accuracy: 0.8444 - auc: 0.9023 - loss: 0.4933 - val_accuracy: 0.5455 - val_auc: 0.9333 - val_loss: 0.6436 - learning_rate: 1.0000e-04
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.8667 - auc: 0.9300 - loss: 0.3189 - val_accuracy: 0.5455 - val_auc: 0.9333 - val_loss: 0.6345 - learning_rate: 1.0000e-04
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 79s 4s/step - accuracy: 0.9333 - auc: 0.9609 - loss: 0.2052 - val_accuracy: 0.5455 - val_auc: 0.9333 - val_loss: 0.6225 - learning_rate: 1.0000e-04
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.8222 - auc: 0.9259 - loss: 0.3218 - val_accuracy: 0.5455 - val_auc: 0.9333 - val_loss: 0.6083 - learning_rate: 1.0000e-04
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.9333 - auc: 0.9835 - loss: 0.1770 - val_accuracy: 0.7273 - val_auc: 0.9333 - val_loss: 0.5955 - learning_rate: 1.0000e-04
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 48s 4s/step - accuracy: 0.9333 - auc: 0.9897 - loss: 0.1342 - val_accuracy: 0.8182 - val_auc: 0.9333 - val_loss: 0.5823 - learning_rate: 1.0000e-04
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 48s 4s/step - accuracy: 0.8889 - auc: 0.9506 - loss: 0.2938 - val_accuracy: 0.8182 - val_auc: 0.9500 - val_loss: 0.5713 - learning_rate: 1.0000e-04
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.9111 - auc: 0.9918 - loss: 0.1391 - val_accuracy: 0.8182 - val_auc: 0.9333 - val_loss: 0.5622 - learning_rate: 1.0000e-04
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 47s 4s/step - accuracy: 0.9111 - auc: 0.9578 - loss: 0.2425 - val_accuracy: 0.8182 - val_auc: 0.9500 - val_loss: 0.5514 - learning_rate: 1.0000e-04
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 48s 4s/step - accuracy: 0.8444 - auc: 0.9383 - loss: 0.3017 - val_accuracy: 0.8182 - val_auc: 0.9500 - val_loss: 0.5439 - learning_rate: 1.0000e-04
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 49s 4s/step - accuracy: 0.8889 - auc: 0.9660 - loss: 0.2397 - val_accuracy: 0.8182 - val_auc: 0.9500 - val_loss: 0.5328 - learning_rate: 1.0000e-04
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 49s 4s/step - accuracy: 0.7556 - auc: 0.8951 - loss: 0.4499 - val_accuracy: 0.7273 - val_auc: 0.9667 - val_loss: 0.5275 - learning_rate: 1.0000e-04
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 48s 4s/step - accuracy: 0.8889 - auc: 0.9815 - loss: 0.1669 - val_accuracy: 0.8182 - val_auc: 0.9667 - val_loss: 0.5146 - learning_rate: 1.0000e-04
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.9778 - auc: 1.0000 - loss: 0.0980 - val_accuracy: 0.8182 - val_auc: 0.9667 - val_loss: 0.5016 - learning_rate: 1.0000e-04
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.9111 - auc: 0.9897 - loss: 0.1803 - val_accuracy: 0.9091 - val_auc: 0.9667 - val_loss: 0.4862 - learning_rate: 1.0000e-04
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 53s 4s/step - accuracy: 0.9111 - auc: 0.9588 - loss: 0.2447 - val_accuracy: 0.8182 - val_auc: 0.9667 - val_loss: 0.4707 - learning_rate: 1.0000e-04
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 48s 4s/step - accuracy: 0.9556 - auc: 0.9897 - loss: 0.1378 - val_accuracy: 0.8182 - val_auc: 0.9667 - val_loss: 0.4559 - learning_rate: 1.0000e-04
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 83s 4s/step - accuracy: 0.8889 - auc: 0.9630 - loss: 0.2540 - val_accuracy: 0.8182 - val_auc: 0.9667 - val_loss: 0.4523 - learning_rate: 1.0000e-04
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# DEBUG: unique classes in y_true → [0 1]
# Fold 2 Metrics:
# accuracy: 0.8182 (CI 0.5455 - 1.0000)
# sensitivity: 0.8333 (CI 0.5000 - 1.0000)
# specificity: 0.8000 (CI 0.3333 - 1.0000)
# auc: 0.9667 (CI 0.8333 - 1.0000)
#
# ========== FOLD 3/5 ==========
# [fusion_model_1 (New)] Training Fold 3
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 171s 7s/step - accuracy: 0.7778 - auc: 0.8189 - loss: 0.5320 - val_accuracy: 0.5455 - val_auc: 0.8333 - val_loss: 0.6742 - learning_rate: 1.0000e-04
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 49s 4s/step - accuracy: 0.8889 - auc: 0.9434 - loss: 0.3218 - val_accuracy: 0.5455 - val_auc: 0.8667 - val_loss: 0.6602 - learning_rate: 1.0000e-04
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 48s 4s/step - accuracy: 0.8444 - auc: 0.8796 - loss: 0.4537 - val_accuracy: 0.5455 - val_auc: 0.8667 - val_loss: 0.6466 - learning_rate: 1.0000e-04
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.9556 - auc: 0.9856 - loss: 0.1667 - val_accuracy: 0.6364 - val_auc: 0.8667 - val_loss: 0.6346 - learning_rate: 1.0000e-04
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.8889 - auc: 0.9753 - loss: 0.1846 - val_accuracy: 0.8182 - val_auc: 0.8667 - val_loss: 0.6242 - learning_rate: 1.0000e-04
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 48s 4s/step - accuracy: 0.8444 - auc: 0.9578 - loss: 0.2691 - val_accuracy: 0.8182 - val_auc: 0.8667 - val_loss: 0.6148 - learning_rate: 1.0000e-04
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 49s 4s/step - accuracy: 0.9111 - auc: 0.9805 - loss: 0.1746 - val_accuracy: 0.8182 - val_auc: 0.8667 - val_loss: 0.6037 - learning_rate: 1.0000e-04
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.8667 - auc: 0.9588 - loss: 0.2776 - val_accuracy: 0.8182 - val_auc: 0.8833 - val_loss: 0.5922 - learning_rate: 1.0000e-04
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 83s 4s/step - accuracy: 0.8667 - auc: 0.9362 - loss: 0.3634 - val_accuracy: 0.8182 - val_auc: 0.8667 - val_loss: 0.5844 - learning_rate: 1.0000e-04
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.9111 - auc: 0.9784 - loss: 0.1982 - val_accuracy: 0.8182 - val_auc: 0.8500 - val_loss: 0.5770 - learning_rate: 1.0000e-04
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 80s 4s/step - accuracy: 0.9333 - auc: 0.9650 - loss: 0.2115 - val_accuracy: 0.8182 - val_auc: 0.8667 - val_loss: 0.5611 - learning_rate: 1.0000e-04
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.8667 - auc: 0.9218 - loss: 0.4008 - val_accuracy: 0.8182 - val_auc: 0.8833 - val_loss: 0.5470 - learning_rate: 1.0000e-04
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 83s 4s/step - accuracy: 0.8444 - auc: 0.9691 - loss: 0.1998 - val_accuracy: 0.9091 - val_auc: 0.9000 - val_loss: 0.5293 - learning_rate: 1.0000e-04
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 48s 4s/step - accuracy: 0.7778 - auc: 0.8961 - loss: 0.4655 - val_accuracy: 0.9091 - val_auc: 0.8667 - val_loss: 0.5179 - learning_rate: 1.0000e-04
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 48s 4s/step - accuracy: 0.8889 - auc: 0.9733 - loss: 0.2117 - val_accuracy: 0.9091 - val_auc: 0.8833 - val_loss: 0.5003 - learning_rate: 1.0000e-04
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.9111 - auc: 0.9835 - loss: 0.1842 - val_accuracy: 0.9091 - val_auc: 0.9000 - val_loss: 0.4834 - learning_rate: 1.0000e-04
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.9111 - auc: 0.9856 - loss: 0.1805 - val_accuracy: 0.9091 - val_auc: 0.9000 - val_loss: 0.4670 - learning_rate: 1.0000e-04
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 48s 4s/step - accuracy: 0.8889 - auc: 0.9578 - loss: 0.2678 - val_accuracy: 0.9091 - val_auc: 0.9000 - val_loss: 0.4496 - learning_rate: 1.0000e-04
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 49s 4s/step - accuracy: 0.9556 - auc: 0.9897 - loss: 0.1369 - val_accuracy: 0.9091 - val_auc: 0.9000 - val_loss: 0.4388 - learning_rate: 1.0000e-04
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 81s 4s/step - accuracy: 0.9111 - auc: 0.9743 - loss: 0.2148 - val_accuracy: 0.9091 - val_auc: 0.9000 - val_loss: 0.4290 - learning_rate: 1.0000e-04
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x796b038c82c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# DEBUG: unique classes in y_true → [0 1]
# Fold 3 Metrics:
# accuracy: 0.9091 (CI 0.7273 - 1.0000)
# sensitivity: 1.0000 (CI 1.0000 - 1.0000)
# specificity: 0.8000 (CI 0.3333 - 1.0000)
# auc: 0.9000 (CI 0.6429 - 1.0000)
#
# ========== FOLD 4/5 ==========
# [fusion_model_1 (New)] Training Fold 4
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 169s 7s/step - accuracy: 0.5556 - auc: 0.6285 - loss: 0.8704 - val_accuracy: 0.7273 - val_auc: 1.0000 - val_loss: 0.6749 - learning_rate: 1.0000e-04
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.8222 - auc: 0.9140 - loss: 0.4409 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.6480 - learning_rate: 1.0000e-04
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 83s 4s/step - accuracy: 0.7333 - auc: 0.8350 - loss: 0.5618 - val_accuracy: 0.9091 - val_auc: 1.0000 - val_loss: 0.6230 - learning_rate: 1.0000e-04
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 48s 4s/step - accuracy: 0.7556 - auc: 0.8462 - loss: 0.5244 - val_accuracy: 0.8182 - val_auc: 1.0000 - val_loss: 0.6067 - learning_rate: 1.0000e-04
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 49s 4s/step - accuracy: 0.8444 - auc: 0.9322 - loss: 0.3408 - val_accuracy: 0.9091 - val_auc: 1.0000 - val_loss: 0.5984 - learning_rate: 1.0000e-04
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 83s 4s/step - accuracy: 0.8667 - auc: 0.9170 - loss: 0.3547 - val_accuracy: 0.9091 - val_auc: 1.0000 - val_loss: 0.5881 - learning_rate: 1.0000e-04
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.9111 - auc: 0.9777 - loss: 0.2152 - val_accuracy: 0.9091 - val_auc: 1.0000 - val_loss: 0.5735 - learning_rate: 1.0000e-04
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 49s 4s/step - accuracy: 0.9111 - auc: 0.9605 - loss: 0.2482 - val_accuracy: 0.9091 - val_auc: 1.0000 - val_loss: 0.5548 - learning_rate: 1.0000e-04
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 48s 4s/step - accuracy: 0.9111 - auc: 0.9626 - loss: 0.2634 - val_accuracy: 0.9091 - val_auc: 1.0000 - val_loss: 0.5359 - learning_rate: 1.0000e-04
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.9111 - auc: 0.9595 - loss: 0.2638 - val_accuracy: 0.9091 - val_auc: 1.0000 - val_loss: 0.5240 - learning_rate: 1.0000e-04
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 80s 4s/step - accuracy: 0.8222 - auc: 0.9038 - loss: 0.4296 - val_accuracy: 0.9091 - val_auc: 1.0000 - val_loss: 0.5154 - learning_rate: 1.0000e-04
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.8222 - auc: 0.9261 - loss: 0.3387 - val_accuracy: 0.9091 - val_auc: 1.0000 - val_loss: 0.5047 - learning_rate: 1.0000e-04
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 48s 4s/step - accuracy: 0.8222 - auc: 0.9332 - loss: 0.3729 - val_accuracy: 0.9091 - val_auc: 1.0000 - val_loss: 0.4913 - learning_rate: 1.0000e-04
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 48s 4s/step - accuracy: 0.8000 - auc: 0.8785 - loss: 0.6210 - val_accuracy: 0.8182 - val_auc: 1.0000 - val_loss: 0.4913 - learning_rate: 1.0000e-04
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 81s 4s/step - accuracy: 0.8667 - auc: 0.9302 - loss: 0.3578 - val_accuracy: 0.8182 - val_auc: 1.0000 - val_loss: 0.4993 - learning_rate: 1.0000e-04
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.9556 - auc: 0.9909 - loss: 0.1429 - val_accuracy: 0.8182 - val_auc: 1.0000 - val_loss: 0.4870 - learning_rate: 1.0000e-04
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 80s 4s/step - accuracy: 0.8667 - auc: 0.9676 - loss: 0.2173 - val_accuracy: 0.8182 - val_auc: 1.0000 - val_loss: 0.4714 - learning_rate: 1.0000e-04
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 87s 5s/step - accuracy: 0.8667 - auc: 0.9646 - loss: 0.2690 - val_accuracy: 0.9091 - val_auc: 1.0000 - val_loss: 0.4503 - learning_rate: 1.0000e-04
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.9556 - auc: 0.9879 - loss: 0.1664 - val_accuracy: 0.9091 - val_auc: 1.0000 - val_loss: 0.4289 - learning_rate: 1.0000e-04
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 49s 4s/step - accuracy: 0.8000 - auc: 0.8988 - loss: 0.4309 - val_accuracy: 0.9091 - val_auc: 1.0000 - val_loss: 0.4203 - learning_rate: 1.0000e-04
# WARNING:tensorflow:6 out of the last 10 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x796afd5e2200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# DEBUG: unique classes in y_true → [0 1]
# Fold 4 Metrics:
# accuracy: 0.9091 (CI 0.7273 - 1.0000)
# sensitivity: 1.0000 (CI 1.0000 - 1.0000)
# specificity: 0.7500 (CI 0.0000 - 1.0000)
# auc: 1.0000 (CI 1.0000 - 1.0000)
#
# ========== FOLD 5/5 ==========
# [fusion_model_1 (New)] Training Fold 5
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 177s 7s/step - accuracy: 0.5111 - auc: 0.5344 - loss: 0.8299 - val_accuracy: 0.6364 - val_auc: 1.0000 - val_loss: 0.6380 - learning_rate: 1.0000e-04
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.8222 - auc: 0.9089 - loss: 0.3943 - val_accuracy: 0.6364 - val_auc: 1.0000 - val_loss: 0.6193 - learning_rate: 1.0000e-04
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 49s 4s/step - accuracy: 0.7778 - auc: 0.8806 - loss: 0.4303 - val_accuracy: 0.6364 - val_auc: 1.0000 - val_loss: 0.6061 - learning_rate: 1.0000e-04
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 48s 4s/step - accuracy: 0.9333 - auc: 0.9555 - loss: 0.2702 - val_accuracy: 0.6364 - val_auc: 1.0000 - val_loss: 0.5967 - learning_rate: 1.0000e-04
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.9111 - auc: 0.9241 - loss: 0.3241 - val_accuracy: 0.6364 - val_auc: 1.0000 - val_loss: 0.5873 - learning_rate: 1.0000e-04
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 49s 4s/step - accuracy: 0.8889 - auc: 0.9879 - loss: 0.2007 - val_accuracy: 0.6364 - val_auc: 1.0000 - val_loss: 0.5776 - learning_rate: 1.0000e-04
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.8667 - auc: 0.9494 - loss: 0.3057 - val_accuracy: 0.9091 - val_auc: 1.0000 - val_loss: 0.5700 - learning_rate: 1.0000e-04
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.9111 - auc: 0.9555 - loss: 0.2567 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.5591 - learning_rate: 1.0000e-04
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.8889 - auc: 0.9798 - loss: 0.2218 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.5477 - learning_rate: 1.0000e-04
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 49s 4s/step - accuracy: 0.8444 - auc: 0.9615 - loss: 0.2629 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.5384 - learning_rate: 1.0000e-04
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 52s 4s/step - accuracy: 0.8667 - auc: 0.9555 - loss: 0.2658 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.5241 - learning_rate: 1.0000e-04
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 79s 4s/step - accuracy: 0.9333 - auc: 0.9656 - loss: 0.2567 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.5157 - learning_rate: 1.0000e-04
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.8444 - auc: 0.9565 - loss: 0.2834 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.5095 - learning_rate: 1.0000e-04
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 49s 4s/step - accuracy: 0.8444 - auc: 0.8897 - loss: 0.4188 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.5052 - learning_rate: 1.0000e-04
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 48s 4s/step - accuracy: 0.8889 - auc: 0.9453 - loss: 0.2978 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.4989 - learning_rate: 1.0000e-04
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.8000 - auc: 0.9099 - loss: 0.3876 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.4892 - learning_rate: 1.0000e-04
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 54s 4s/step - accuracy: 0.8000 - auc: 0.9231 - loss: 0.3732 - val_accuracy: 0.9091 - val_auc: 1.0000 - val_loss: 0.4738 - learning_rate: 1.0000e-04
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 85s 5s/step - accuracy: 0.8667 - auc: 0.9302 - loss: 0.3302 - val_accuracy: 0.9091 - val_auc: 1.0000 - val_loss: 0.4544 - learning_rate: 1.0000e-04
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.9333 - auc: 0.9757 - loss: 0.2199 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.4358 - learning_rate: 1.0000e-04
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.8222 - auc: 0.9281 - loss: 0.3424 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.4217 - learning_rate: 1.0000e-04
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# DEBUG: unique classes in y_true → [0 1]
# Fold 5 Metrics:
# accuracy: 1.0000 (CI 1.0000 - 1.0000)
# sensitivity: 1.0000 (CI 1.0000 - 1.0000)
# specificity: 1.0000 (CI 1.0000 - 1.0000)
# auc: 1.0000 (CI 1.0000 - 1.0000)
#
# ========== FINAL AGGREGATED RESULTS ==========
# Final Cross-Validated Performance:
# accuracy: 0.9107 (CI 0.8393 - 0.9821) | CV Mean±SD: 0.9106 ± 0.0576
# sensitivity: 0.9394 (CI 0.8519 - 1.0000) | CV Mean±SD: 0.9381 ± 0.0762
# specificity: 0.8696 (CI 0.7083 - 1.0000) | CV Mean±SD: 0.8700 ± 0.1077
# auc: 0.9460 (CI 0.8697 - 1.0000) | CV Mean±SD: 0.9505 ± 0.0488
# [fusion_model_1 (New)] K-Fold training completed successfully
# 📈 Learning curve saved → /content/drive/MyDrive/mResearch/outputs/fusion_model_1 (New)/plots/learning_curve.png
#
# 📊 Aggregating predictions across folds...
# ✔ Saved aggregated predictions to: /content/drive/MyDrive/mResearch/outputs/fusion_model_1 (New)/predictions/internal/aggregated_predictions.npz
#
# 📈 Generating ROC Curve...
#
# 📊 Clinical Table:
#                              Value
# accuracy     0.911 (0.821 - 0.982)
# sensitivity  0.939 (0.844 - 1.000)
# specificity  0.870 (0.722 - 1.000)
# auc          0.946 (0.867 - 1.000)
# [fusion_model_1 (New)] ✅ K-Fold experiment completed successfully

# %%
print("🌍 Running External Validation...")

run_external(cfg)
# Out:
# 🌍 Running External Validation...
#
# 🌍 Running External Validation
#
# 🌍 Loading EXTERNAL data...
#
# 📂 Loading dataset from: /content/drive/MyDrive/mResearch/datasets/testing
# Class 'Glaucoma': 35 aligned samples
# Class 'Non-glaucoma': 47 aligned samples
#
# ✅ Total aligned samples: 82
#
# 📦 Loading fold models...
# ✔ Loading model: /content/drive/MyDrive/mResearch/outputs/fusion_model_1 (New)/models/fold_0_best.keras
# ✔ Loading model: /content/drive/MyDrive/mResearch/outputs/fusion_model_1 (New)/models/fold_1_best.keras
# ✔ Loading model: /content/drive/MyDrive/mResearch/outputs/fusion_model_1 (New)/models/fold_2_best.keras
# ✔ Loading model: /content/drive/MyDrive/mResearch/outputs/fusion_model_1 (New)/models/fold_3_best.keras
# ✔ Loading model: /content/drive/MyDrive/mResearch/outputs/fusion_model_1 (New)/models/fold_4_best.keras
#
# 🧠 Ensembling predictions...
#
# 🔍 SANITY CHECK
# y_true: 82
# y_prob: 82
#
# 📊 Computing metrics...
# ✅ Saved external predictions → /content/drive/MyDrive/mResearch/outputs/fusion_model_1 (New)/predictions/external/external_predictions.npz
#
# 📈 Generating ROC Curve...
#
# 📊 Clinical Table:
#                              Value
# accuracy     0.915 (0.854 - 0.976)
# sensitivity  1.000 (1.000 - 1.000)
# specificity  0.800 (0.656 - 0.933)
# auc          0.971 (0.932 - 0.999)
#
# 🌍 External Results:
# accuracy: 0.9146341463414634
# sensitivity: 1.0
# specificity: 0.8
# auc: 0.9708206686930091
# accuracy_ci: (0.8536585365853658, 0.975609756097561)
# sensitivity_ci: (1.0, 1.0)
# specificity_ci: (0.6562230603448276, 0.9334374999999999)
# auc_ci: (0.9318998495594241, 0.999416866028708)
# [fusion_model_1 (New)] ✅ External validation completed successfully
